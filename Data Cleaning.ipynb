# %%
import pandas as pd
df = pd.read_csv("TMDB_all_movies.csv")
df
# Out:
#               id                             title  vote_average  vote_count  \
# 0              2                             Ariel           7.1       356.0
# 1              3               Shadows in Paradise           7.3       426.0
# 2              5                        Four Rooms           5.9      2776.0
# 3              6                    Judgment Night           6.5       360.0
# 4              8  Life in Loops (A Megacities RMX)           7.2        30.0
# ...          ...                               ...           ...         ...
# 1148803  1613844                Bumbling Ballerina           0.0         0.0
# 1148804  1613845                          Boutique           0.0         0.0
# 1148805  1613848           My Husband's Mistress 2           0.0         0.0
# 1148806  1613849                           我们为何要做梦           0.0         0.0
# 1148807  1613851            Love Track: Finding Us           0.0         0.0
#
# ...

# %%
df.isnull().sum()
# Out:
# id                               0
# title                           14
# vote_average                     0
# vote_count                       0
# status                           0
# release_date                118829
# revenue                          0
# runtime                          0
# budget                           0
# imdb_id                     500724
# original_language                0
# original_title                  13
# overview                    175599
# popularity                       0
# tagline                     975500
# genres                      310955
# production_companies        597820
# production_countries        428703
# spoken_languages            421916
# cast                        366652
# director                    186199
# director_of_photography     845989
# writers                     569884
# producers                   760538
# music_composer             1022362
# imdb_rating                 690547
# imdb_votes                  690547
# ...

# %%
df = df.dropna()

# %%
df.to_csv('cleaned_movies.csv', index=False)
